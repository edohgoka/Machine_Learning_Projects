# %%
# !wget https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip
# Out:
# --2021-08-30 12:58:13--  https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_3367a.zip
# Resolving download.microsoft.com (download.microsoft.com)... 96.16.104.154, 2600:1417:8000:9b2::e59, 2600:1417:8000:980::e59
# Connecting to download.microsoft.com (download.microsoft.com)|96.16.104.154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 824894548 (787M) [application/octet-stream]
# Saving to: ‘kagglecatsanddogs_3367a.zip’
#
# kagglecatsanddogs_3 100%[===================>] 786.68M   122MB/s    in 6.5s
#
# 2021-08-30 12:58:20 (121 MB/s) - ‘kagglecatsanddogs_3367a.zip’ saved [824894548/824894548]

# %%
# !unzip -q "/content/kagglecatsanddogs_3367a.zip"

# %%
# !ls "PetImages/"
# Out:
# Cat  Dog

# %%
## Importing necessary libraries for this project
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import os
from tqdm import tqdm

# %%
# Number of Dogs Images
len(os.listdir("PetImages/Dog"))
# Out:
# 12501

# %%
# Number of Cats Images
len(os.listdir("PetImages/Cat"))
# Out:
# 12501

# %%
DataPath = pathlib.Path("PetImages")
all_paths = DataPath.glob("*/*.jpg")
all_paths
# Out:
# <generator object Path.glob at 0x7f8e28963e50>

# %%
all_paths = list(all_paths)
all_paths[:5]
# Out:
# [PosixPath('PetImages/Cat/11361.jpg'),
#  PosixPath('PetImages/Cat/151.jpg'),
#  PosixPath('PetImages/Cat/9805.jpg'),
#  PosixPath('PetImages/Cat/5493.jpg'),
#  PosixPath('PetImages/Cat/6971.jpg')]

# %%
all_paths = list(map(lambda x: str(x), all_paths))
all_paths[:5]
# Out:
# ['PetImages/Cat/11361.jpg',
#  'PetImages/Cat/151.jpg',
#  'PetImages/Cat/9805.jpg',
#  'PetImages/Cat/5493.jpg',
#  'PetImages/Cat/6971.jpg']

# %%
from random import shuffle

# %%
shuffle(all_paths)
all_paths[:10]
# Out:
# ['PetImages/Cat/4850.jpg',
#  'PetImages/Cat/1043.jpg',
#  'PetImages/Dog/5358.jpg',
#  'PetImages/Dog/2640.jpg',
#  'PetImages/Cat/726.jpg',
#  'PetImages/Cat/2175.jpg',
#  'PetImages/Cat/7708.jpg',
#  'PetImages/Cat/6680.jpg',
#  'PetImages/Dog/9998.jpg',
#  'PetImages/Cat/11922.jpg']

# %%
def testImageQuality(paths):
  new_paths = []

  for path in tqdm(paths):
    try:
      image = tf.io.read_file(path)
      image = tf.io.decode_jpeg(image, channels=3)
    except:
      continue
    new_paths.append(path)
  return new_paths

# %%
all_paths = testImageQuality(all_paths)
all_paths[:10]
# Out:
# 100%|██████████| 25000/25000 [00:45<00:00, 543.95it/s]
# ['PetImages/Cat/4850.jpg',
#  'PetImages/Cat/1043.jpg',
#  'PetImages/Dog/5358.jpg',
#  'PetImages/Dog/2640.jpg',
#  'PetImages/Cat/726.jpg',
#  'PetImages/Cat/2175.jpg',
#  'PetImages/Cat/7708.jpg',
#  'PetImages/Cat/6680.jpg',
#  'PetImages/Dog/9998.jpg',
#  'PetImages/Cat/11922.jpg']

# %%
# Getting their respective labels
def get_label(image_path):
  return image_path.split("/")[-2]

# %%
all_labels = list(map(lambda x: get_label(x), all_paths))
all_labels[:10]
# Out:
# ['Cat', 'Cat', 'Dog', 'Dog', 'Cat', 'Cat', 'Cat', 'Cat', 'Dog', 'Cat']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Le = LabelEncoder()
all_labels = Le.fit_transform(all_labels)

all_labels[:10]
# Out:
# array([0, 0, 1, 1, 0, 0, 0, 0, 1, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
train_paths, val_paths, train_labels, val_labels = train_test_split(all_paths, all_labels)

# %%
train_paths[:10], train_labels[:10]
# Out:
# (['PetImages/Dog/2228.jpg',
#   'PetImages/Dog/1786.jpg',
#   'PetImages/Dog/1916.jpg',
#   'PetImages/Cat/9750.jpg',
#   'PetImages/Cat/7484.jpg',
#   'PetImages/Dog/4716.jpg',
#   'PetImages/Dog/1373.jpg',
#   'PetImages/Dog/7896.jpg',
#   'PetImages/Cat/6263.jpg',
#   'PetImages/Cat/11662.jpg'],
#  array([1, 1, 1, 0, 0, 1, 1, 1, 0, 0]))

# %%
len(train_paths)
# Out:
# 18618

# %%
# Function used to decode jpeg into Tensor

def load(image, label):
  image = tf.io.read_file(image)
  image = tf.io.decode_jpeg(image, channels=3) # we are getting here the image tensor
  return image, label

# %%
# Define Image size and batch size
img_size = 224
batch_size = 128

# Basic transformation 
resize = tf.keras.Sequential([
         tf.keras.layers.experimental.preprocessing.Resizing(img_size, img_size)
])

# Data augmentation 
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
    tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=(-0.3, -0.2))
])

# %%
# Function used to create a Tensorflow data object
autotune = tf.data.experimental.AUTOTUNE

def get_dataset(paths, labels, train=True):
  image_paths = tf.convert_to_tensor(paths)
  labels = tf.convert_to_tensor(labels)

  image_dataset = tf.data.Dataset.from_tensor_slices(image_paths)
  labels_dataset = tf.data.Dataset.from_tensor_slices(labels)

  dataset = tf.data.Dataset.zip((image_dataset, labels_dataset))

  dataset = dataset.map(lambda image, label: load(image, label))
  dataset = dataset.map(lambda image, label: (resize(image), label), num_parallel_calls=autotune)
  dataset = dataset.shuffle(1000)
  dataset = dataset.batch(batch_size)

  if train:
    dataset = dataset.map(lambda image, label: (data_augmentation(image), label), num_parallel_calls=autotune)
    dataset = dataset.repeat()

  return dataset

# %%
# Creating train dataset object and verifying it
# %time train_dataset = get_dataset(train_paths, train_labels)

image, label = next(iter(train_dataset))
print(image.shape)
print(label.shape)
# Out:
# CPU times: user 506 ms, sys: 13.6 ms, total: 520 ms
# Wall time: 553 ms
# (128, 224, 224, 3)
# (128,)

# %%
train_dataset
# Out:
# <RepeatDataset shapes: ((None, 224, 224, 3), (None,)), types: (tf.float32, tf.int64)>

# %%
# View a sample training image
print(Le.inverse_transform(label)[1])
plt.imshow((image[1].numpy()/255).reshape(224, 224, 3))
# Out:
# Cat

# %%
# Creating validation dataset object and verifying it
# %time val_dataset = get_dataset(val_paths, val_labels, train=False)

image, label = next(iter(val_dataset))
print(image.shape)
print(label.shape)
# Out:
# CPU times: user 28.7 ms, sys: 1.07 ms, total: 29.8 ms
# Wall time: 36 ms
# (128, 224, 224, 3)
# (128,)

# %%
print(Le.inverse_transform(label)[1])
plt.imshow((image[1].numpy()/255).reshape(224, 224, 3))
# Out:
# Dog

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization, GlobalMaxPool2D

# %%
## Building Inception model

from tensorflow.keras.applications import InceptionV3

backbone = InceptionV3(
    input_shape = (224, 224, 3),
    include_top = False
)

model = tf.keras.Sequential([
                             backbone,
                             tf.keras.layers.GlobalAveragePooling2D(),
                             tf.keras.layers.Dense(1, activation="sigmoid")
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 2s 0us/step
# 87924736/87910968 [==============================] - 2s 0us/step

# %%
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Functional)    (None, 5, 5, 2048)        21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# _________________________________________________________________
# None

# %%
model.compile(
    loss = "binary_crossentropy",
    optimizer = "adam",
    metrics = ["accuracy"]
)

# %%
# Training the model
history = model.fit(
    train_dataset,
    steps_per_epoch = len(train_paths)//batch_size,
    epochs = 10,
    validation_data = val_dataset,
    validation_steps = len(val_paths)//batch_size,
)
# Out:
# Epoch 1/10
# 145/145 [==============================] - 417s 3s/step - loss: 0.1821 - accuracy: 0.9280 - val_loss: 0.6923 - val_accuracy: 0.7030
# Epoch 2/10
# 145/145 [==============================] - 378s 3s/step - loss: 0.1102 - accuracy: 0.9582 - val_loss: 0.3026 - val_accuracy: 0.8864
# Epoch 3/10
# 145/145 [==============================] - 377s 3s/step - loss: 0.0940 - accuracy: 0.9634 - val_loss: 0.9933 - val_accuracy: 0.5635
# Epoch 4/10
# 145/145 [==============================] - 371s 3s/step - loss: 0.0948 - accuracy: 0.9629 - val_loss: 0.1912 - val_accuracy: 0.9178
# Epoch 5/10
# 145/145 [==============================] - 378s 3s/step - loss: 0.0760 - accuracy: 0.9700 - val_loss: 0.2370 - val_accuracy: 0.9049
# Epoch 6/10
# 145/145 [==============================] - 373s 3s/step - loss: 0.0744 - accuracy: 0.9698 - val_loss: 0.4768 - val_accuracy: 0.7948
# Epoch 7/10
# 145/145 [==============================] - 375s 3s/step - loss: 0.0690 - accuracy: 0.9731 - val_loss: 0.1534 - val_accuracy: 0.9329
# Epoch 8/10
# 145/145 [==============================] - 374s 3s/step - loss: 0.0658 - accuracy: 0.9736 - val_loss: 0.1298 - val_accuracy: 0.9450
# Epoch 9/10
# 145/145 [==============================] - 372s 3s/step - loss: 0.0641 - accuracy: 0.9761 - val_loss: 0.2512 - val_accuracy: 0.8750
# Epoch 10/10
# 145/145 [==============================] - 375s 3s/step - loss: 0.0624 - accuracy: 0.9758 - val_loss: 0.3518 - val_accuracy: 0.8988

# %%
# Evaluating the model
loss, acc = model.evaluate(val_dataset)

print("Testing Acc : ", acc)
print("Testing Loss : ", loss)
# Out:
# 49/49 [==============================] - 38s 754ms/step - loss: 0.3534 - accuracy: 0.8986
# Testing Acc :  0.8986464738845825
# Testing Loss :  0.35344305634498596
